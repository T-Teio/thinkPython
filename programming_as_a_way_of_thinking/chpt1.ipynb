# %% [markdown]
# # Arithmetic Operators

# %% [markdown]
# skipping this lol
# ** (to the power of)
# // (floor divide - get rid of decimal place stuff lol)

# %% [markdown]
# % (modulus division gives remainder after division as funny answer)

# %% [markdown]
# ## 1.2 Expressions

# %% [markdown]
# Expression - A collection of operators and numbers is called an expression
#
# example:
# 6 + 6 ** 2
# 36 + 6
# 42
#
# (12 + 5) * 6
# 17 * 6
# 102
#
# 12 + 5 * 6
# 12 + 30
# 42
#
# myVar = var1 * var2 + var3

# %% [markdown]
# ## 1.3 Arithmetic functions

# %% [markdown]
# python is a modular language:
# * Core Python Code
# * External Modules
# import math
#
# Python like any other programming language has built in functions
#
# **round()** - this function takes a floating-point number and rounds it off to the nearest integer

# %%
round(42.2)
# Out:
# 42

# %%
round(42.6)
# Out:
# 43

# %% [markdown]
# abs() function - computes the absolute value of a number

# %%
abs(42)
# Out:
# 42

# %%
abs(-42)
# Out:
# 42

# %% [markdown]
# #### Calling a function / Function call

# %% [markdown]
# The process of using a function within your code
#
# Whenever you call a function the parenthesis are required

# %%
abs 42
# Out:
#   Cell In[5], line 1
#     abs 42
#         ^
# SyntaxError: invalid syntax

# %%
abs
# Out:
# <function abs(x, /)>

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round(3.14159, 2)
# Out:
# 3.14

# %% [markdown]
# ## 1.4 Strings

# %% [markdown]
# A string is a sequence of characters that are delimited by quotation marks (either single or double as long as they match).
#
# myStr = "This is my string #^!!04&9"

# %%
"Hello"
# Out:
# 'Hello'

# %%
"world"
# Out:
# 'world'

# %%
"it's a small world"
# Out:
# "it's a small world"

# %%
# Escape Character \ - This tells the interpreter not to process the next character
'it\'s a small world'
# Out:
# "it's a small world"

# %% [markdown]
# ### The + symbol with Strings - Concatination

# %%
#Concatination symbol + - the + sign concatinates (connects together 2 strings)
"well, " + "it's a small world" + " after all."
# Out:
# "well, it's a small world after all."

# %% [markdown]
# # Strings and the * Operator

# %% [markdown]
# The * operator works with strings by making copie of a string and concatenates them together.

# %%
"Spam, " * 4
# Out:
# 'Spam, Spam, Spam, Spam, '

# %% [markdown]
# # Strings and the len() function

# %%
len("Spam")
# Out:
# 4

# %%
`Hello`
# Out:
#   Cell In[17], line 1
#     `Hello`
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.5 Values and types

# %%
# function -  Python will tell youwhat type of
# data something is

# %%
type(42.)
# Out:
# float

# %%
type("Hello")
# Out:
# str

# %%
# int() funciton - changes a valid floating-point number to an integer

int(42.5)
# Out:
# 42

# %%
# float() function changes a valid integer to a floating-point number
float(42)
# Out:
# 42.0

# %%
'126'
# Out:
# '126'

# %%
type('126')
# Out:
# str

# %%
'126' / 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 '126' / 3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
int('126') / 3
# Out:
# 42.0

# %%
float('12.6') * 3
# Out:
# 37.8

# %% [markdown]
# ### Natural Language
#
# are languages people speak, like english, spanish, and french. They where not technically were not designed by people, naturally evolved from human speech.

# %% [markdown]
# ### Formal Language
#
# are languages that are designed by people for specific applications. For example, the notation that mathmaticians use as a formal language that is particularly good at denoting relaitonships among numbers and symbols.
#
#
# ### Debugging
#
# Mistakes made in the process of programming have been come to be known as bugs. Tracking down and fixing those mistakes then became known as debugging.
